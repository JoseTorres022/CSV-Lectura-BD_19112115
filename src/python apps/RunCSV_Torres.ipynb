# %%
import pandas as pd

datos=pd.read_csv('./resources/AnalisisRLE.csv',index_col=False, delimiter=',')
datos.head()
# Out:
#    Layer Component  Pin Status  Comment               Defect  \
# 0      1    C206_1  NaN      F      NaN  INSUFFICIENT SOLDER
# 1      1    C212_1  NaN      F      NaN                Short
# 2      1    C214_1  NaN      F      NaN  INSUFFICIENT SOLDER
# 3      1    C215_1  NaN      F      NaN                Short
# 4      1    C216_1  NaN      F      NaN  INSUFFICIENT SOLDER
#
#              JointType        Subtype  Xloc  Yloc
# 0  INSUFFICIENT SOLDER  C0402H0_55V1A     0     0
# 1                Short  C0402H0_55V1A     0     0
# 2  INSUFFICIENT SOLDER  C0402H0_55V1A     0     0
# 3                Short  C0402H0_55V1A     0     0
# 4  INSUFFICIENT SOLDER  C0402H0_55V1A     0     0
